# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('og-eecs.csv')

# %%
# Drop columns
to_drop = ["same_subjects", "course_desc"]
df.drop(to_drop, inplace=True, axis=1)

# %%
# Remove course_code in course_title
# Remove "" in course_title
count = 0
for course in df['course_title']:
    course = course.strip('\"')        
    course = course.split(' ') 
    course =  " ".join(course[1:])
    df.iat[count, 0] = course
    count += 1

# %%
# Remove courses that show up more than two times
ununique = df['course_title'].value_counts()
ununique = ununique[ununique > 2]
ununique = ununique.keys().tolist()

for course in ununique:
    df = df.drop(df[df["course_title"] == course].index)

# %%
df.head()
# Out:
#                                         course_title course_code  \
# 0  Introduction to Computer Science Programming i...      6.0001
# 1  Introduction to Computational Thinking and Dat...      6.0002
# 3                           Circuits and Electronics       6.002
# 4                                  Signal Processing       6.003
# 5                             Computation Structures       6.004
#
#                            prereq_courses
# 0                                      []
# 1                              ['6.0001']
# 3  ['8.02|8.021|8.022', '2.087', '18.03']
# 4                     ['6.0001', '18.03']
# 5          ['8.02|8.021|8.022', '6.0001']

# %%
count = 4
a = df["course_code"][count]
print(f" sdkfj {a} ksdf")
# Out:
#  sdkfj 6.003 ksdf

# %%
codes = df["course_code"].tolist()
codes
    
count = 0

for prereqs in df["prereq_courses"]:
    prereqs = prereqs.strip('][').split(', ')

    temp = []

    for prereq in prereqs:
        prereq = prereq.strip("\'").split("|")
        temp.extend(prereq)
                
    prereq = [req for req in temp if req in codes]
        
    df.iat[count,2] = prereq
    
    count += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/qiaochloe/Documents/coding/MIT/eecs/pandas-csv-export/eecs-clean.ipynb Cell 8' in <module>
#       <a href='vscode-notebook-cell:/Users/qiaochloe/Documents/coding/MIT/eecs/pandas-csv-export/eecs-clean.ipynb#ch0000006?line=3'>4</a> count = 0
#       <a href='vscode-notebook-cell:/Users/qiaochloe/Documents/coding/MIT/eecs/pandas-csv-export/eecs-clean.ipynb#ch0000006?line=5'>6</a> for prereqs in df["prereq_courses"]:
# ----> <a href='vscode-notebook-cell:/Users/qiaochloe/Documents/coding/MIT/eecs/pandas-csv-export/eecs-clean.ipynb#ch0000006?line=6'>7</a>     prereqs = prereqs.strip('][').split(', ')
#       <a href='vscode-notebook-cell:/Users/qiaochloe/Documents/coding/MIT/eecs/pandas-csv-export/eecs-clean.ipynb#ch0000006?line=8'>9</a>     temp = []
# ...

# %%
df.head()
# Out:
#                                         course_title course_code  \
# 0  Introduction to Computer Science Programming i...      6.0001
# 1  Introduction to Computational Thinking and Dat...      6.0002
# 3                           Circuits and Electronics       6.002
# 4                                  Signal Processing       6.003
# 5                             Computation Structures       6.004
#
#   prereq_courses
# 0             []
# 1       [6.0001]
# 3             []
# 4       [6.0001]
# 5       [6.0001]

# %%
codes = df["course_code"].tolist()
codes

that = "['6.042', '6.0001', '6.009']"
that = that.strip('][').split(', ')

temp = []

for prereq in that:
    prereq = prereq.strip("\'").split("|")
    temp.extend(prereq)

prereq = [req for req in temp if req in codes]
prereq
    #print(prereqs)

    #cleaned_prereqs = []
    
    #for prereq in prereqs:
    #    print(prereq)
    #    
    #    print(prereq)
    #    # cleaned_prereqs.extend(prereq)
        
    #print(cleaned_prereqs)
# Out:
# ['6.0001', '6.009']

# %%
for prereqs in df["prereq_courses"]:
    print(prereqs)
    prereqs = prereqs.strip("\'")
    prereqs = prereqs.strip('][').split(', ')
    print(prereqs)

    cleaned_prereqs = []
    
    for prereq in prereqs:
        print(prereq)
        prereq = prereq.strip("\"").split("|")
        print(prereq)
        # cleaned_prereqs.extend(prereq)
        
    print(cleaned_prereqs)

# %%
for row in df:
    for item in df[row]:
        print(item)
# Out:
# Introduction to Computer Science Programming in Python
# Introduction to Computational Thinking and Data Science
# Circuits and Electronics
# Signal Processing
# Computation Structures
# Introduction to Algorithms
# Introduction to Inference
# Fundamentals of Programming
# Introduction to EECS via Robotics
# Signals, Systems and Inference
# Nanoelectronics and Computing Systems
# Electromagnetics Waves and Applications
# Electromagnetic Fields, Forces and Motion
# Introduction to EECS via Communication Networks
# Cellular Neurophysiology and Computing
# Quantitative and Clinical Physiology
# Fields, Forces and Flows in Biological Systems
# Molecular, Cellular, and Tissue Biomechanics
# Medical Device Design
# Biomedical Signal and Image Processing (New)
# Biomolecular Feedback Systems
# Introduction to EECS via Medical Technology
# Elements of Software Construction
# Computer Systems Engineering
# Artificial Intelligence
# Computer Language Engineering
# ...
